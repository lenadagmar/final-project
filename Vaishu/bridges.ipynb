# %% [markdown]
# As Pittsburgh is the city of bridges, we will be looking at the various different bridges in all of the neighborhoods. Our ideal neighborhood has as many bridges as possible because bridges are a core part of the city's history.

# %%
import pandas as pd
bridges = pd.read_csv("bridges.csv")
bridges[['name', 'year built', 'neighborhood']]
# Out:
#                                        name  year built  \
# 0                        Fort Duquesne Blvd         NaN
# 1                        28th Street Bridge      1931.0
# 2                      Second Avenue Bridge      1886.0
# 3                   Alexander Street Bridge      1924.0
# 4          Millvale Trail Pedestrian Bridge         NaN
# ..                                      ...         ...
# 148  Mon Wharf Switchback Pedestrian Bridge         NaN
# 149                          North Shore Dr         NaN
# 150       Parking Lot Bridge at Woodruff St         NaN
# 151                             Seventh Ave         NaN
# 152        Crosstown Blvd Pedestrian Bridge         NaN
#
#                   neighborhood
# 0    Central Business District
# 1               Strip District
# 2               Swisshelm Park
# 3                     West End
# 4                    Troy Hill
# ..                         ...
# 148  Central Business District
# 149                North Shore
# 150           Mount Washington
# 151  Central Business District
# 152  Central Business District
#
# [153 rows x 3 columns]
