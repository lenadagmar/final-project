# %% [markdown]
# As Pittsburgh is the city of bridges, we will be looking at the various different bridges in all of the neighborhoods. Our ideal neighborhood has as many bridges as possible because bridges are a core part of the city's history.

# %%
import pandas as pd
bridges = pd.read_csv("bridges.csv")
bridges[['name', 'neighborhood']]
# Out:
#                                        name               neighborhood
# 0                        Fort Duquesne Blvd  Central Business District
# 1                        28th Street Bridge             Strip District
# 2                      Second Avenue Bridge             Swisshelm Park
# 3                   Alexander Street Bridge                   West End
# 4          Millvale Trail Pedestrian Bridge                  Troy Hill
# ..                                      ...                        ...
# 148  Mon Wharf Switchback Pedestrian Bridge  Central Business District
# 149                          North Shore Dr                North Shore
# 150       Parking Lot Bridge at Woodruff St           Mount Washington
# 151                             Seventh Ave  Central Business District
# 152        Crosstown Blvd Pedestrian Bridge  Central Business District
#
# [153 rows x 2 columns]

# %% [markdown]
# This database is a list of a portion of the bridges in Pittsburgh and what neighborhood they are located in.

# %%
nbhdBridges = {}

for nbhd in bridges['neighborhood']:
    bridgeCount = 0
    for bridge in range(len(bridges)):
        if bridges.iloc[bridge, 8] == nbhd:
            bridgeCount += 1
        nbhdBridges[nbhd] = bridgeCount
    if nbhd not in nbhdBridges:
        nbhdBridges[nbhd] = 0
    
nbhds = pd.DataFrame.from_dict(nbhdBridges, orient = 'index')
nbhds = nbhds.sort_values(0, ascending = False)
new= "number of bridges"
nbhds.index.rename(new, inplace = True)
nbhds.head(100)

#number of parks in each neighborhood, descending order
# Out:
#                             0
# number of bridges
# Squirrel Hill South        14
# Central Business District  12
# Troy Hill                   7
# Overbrook                   6
# Hays                        6
# Shadyside                   6
# Oakwood                     5
# South Side Slopes           5
# South Side Flats            5
# West End                    4
# South Oakland               4
# Mount Washington            4
# East Allegheny              4
# Hazelwood                   4
# Bon Air                     3
# Larimer                     3
# Allegheny Center            3
# Sheraden                    3
# Polish Hill                 3
# Bloomfield                  2
# Bluff                       2
# Lincoln-Lemington-Belmar    2
# Swisshelm Park              2
# Allegheny West              2
# Windgap                     2
# Highland Park               2
# Squirrel Hill North         2
# Arlington                   2
# Perry South                 2
# ...

# %% [markdown]
# This table lists the number of bridges per neighborhood in Pittsburgh.

# %%
nbhds.describe()
# Out:
#                0
# count  53.000000
# mean    2.811321
# std     2.616932
# min     0.000000
# 25%     1.000000
# 50%     2.000000
# 75%     4.000000
# max    14.000000

# %% [markdown]
# Since the mean is 2.8, we will elimate all the neighborhoods with less than 3 parks.

# %%
nbhds = (nbhds.loc[nbhds[0] > 3])
nbhds.head(10)
# Out:
#                             0
# number of bridges
# Squirrel Hill South        14
# Central Business District  12
# Troy Hill                   7
# Overbrook                   6
# Hays                        6
# Shadyside                   6
# Oakwood                     5
# South Side Slopes           5
# South Side Flats            5
# West End                    4

# %%
nbhds[:10].plot(kind = 'bar', title = "Number of Bridges")

# %% [markdown]
# These are the top ten finalists for prettiest neighborhood in terms of the number of bridges in each neighborhood.
